# %%
import pandas as pd

urban_df = pd.read_csv("urban_surface.csv")

# %%
X = urban_df[structural_vars].copy()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.decomposition import PCA

pca = PCA()
principal_components = pca.fit_transform(X_scaled)

# %%
import pandas as pd

explained_variance = pd.DataFrame({
    "Component": [f"PC{i+1}" for i in range(len(pca.explained_variance_ratio_))],
    "Explained Variance Ratio": pca.explained_variance_ratio_
})

explained_variance
# Out:
#   Component  Explained Variance Ratio
# 0       PC1                  0.467507
# 1       PC2                  0.170964
# 2       PC3                  0.167512
# 3       PC4                  0.159709
# 4       PC5                  0.023933
# 5       PC6                  0.010375

# %%
loadings = pd.DataFrame(
    pca.components_.T,
    columns=[f"PC{i+1}" for i in range(len(structural_vars))],
    index=structural_vars
)

loadings
# Out:
#                                    PC1       PC2       PC3       PC4  \
# tree_cover_pct               -0.565973 -0.055527 -0.024866 -0.037779
# asphalt_pct                   0.581177  0.008058 -0.039283  0.033222
# building_density             -0.578196 -0.031756  0.012510 -0.043223
# heat_retention_factor         0.008491 -0.512666  0.717493  0.471193
# social_vulnerability_index   -0.010470 -0.557469 -0.694228  0.452502
# infrastructure_quality_index -0.086110  0.649804 -0.030537  0.754201
#
#                                    PC5       PC6
# tree_cover_pct                0.817243  0.081612
# asphalt_pct                   0.329241  0.742376
# building_density             -0.470534  0.664269
# heat_retention_factor         0.013690  0.009726
# social_vulnerability_index   -0.042968 -0.023682
# infrastructure_quality_index  0.016695  0.017588
